# %%
from sklearn.model_selection import train_test_split

# %%
import seaborn as ses

# %%
from sklearn.neighbors import KNeighborsClassifier as KNeighbor

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
data =pd.read_csv('neo_v2.csv')

# %%
data.isnull().sum()
# Out:
# id                    0
# name                  0
# est_diameter_min      0
# est_diameter_max      0
# relative_velocity     0
# miss_distance         0
# orbiting_body         0
# sentry_object         0
# absolute_magnitude    0
# hazardous             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90836 entries, 0 to 90835
# Data columns (total 10 columns):
# id                    90836 non-null int64
# name                  90836 non-null object
# est_diameter_min      90836 non-null float64
# est_diameter_max      90836 non-null float64
# relative_velocity     90836 non-null float64
# miss_distance         90836 non-null float64
# orbiting_body         90836 non-null object
# sentry_object         90836 non-null bool
# absolute_magnitude    90836 non-null float64
# hazardous             90836 non-null bool
# dtypes: bool(2), float64(5), int64(1), object(2)
# memory usage: 5.7+ MB

# %%
#Dectionaries to store Accuricies BY K negibours every time
train_accurcy={}
test_accurcy={}

# %%
data=data.drop("name",axis=1)
data=data.drop("id",axis=1)
data=data.drop("sentry_object",axis=1)
data=data.drop("orbiting_body",axis=1)

# %%
data
# Out:
#        est_diameter_min  est_diameter_max  relative_velocity  miss_distance  \
# 0              1.198271          2.679415       13569.249224   5.483974e+07
# 1              0.265800          0.594347       73588.726663   6.143813e+07
# 2              0.722030          1.614507      114258.692129   4.979872e+07
# 3              0.096506          0.215794       24764.303138   2.543497e+07
# 4              0.255009          0.570217       42737.733765   4.627557e+07
# ...                 ...               ...                ...            ...
# 90831          0.026580          0.059435       52078.886692   1.230039e+07
# 90832          0.016771          0.037501       46114.605073   5.432121e+07
# 90833          0.031956          0.071456        7566.807732   2.840077e+07
# 90834          0.007321          0.016370       69199.154484   6.869206e+07
# 90835          0.039862          0.089133       27024.455553   5.977213e+07
#
#        absolute_magnitude  hazardous
# ...

# %%
y=data['hazardous']
x =data.iloc[:, 0:5]

# %%
x_train,x_test,y_train,y_test =train_test_split(x,y,test_size=.3)

# %%
data.hazardous.value_counts().plot(kind='bar')
plt.title('Hazardous')
plt.show()

# %%
x
# Out:
#        est_diameter_min  est_diameter_max  relative_velocity  miss_distance  \
# 0              1.198271          2.679415       13569.249224   5.483974e+07
# 1              0.265800          0.594347       73588.726663   6.143813e+07
# 2              0.722030          1.614507      114258.692129   4.979872e+07
# 3              0.096506          0.215794       24764.303138   2.543497e+07
# 4              0.255009          0.570217       42737.733765   4.627557e+07
# ...                 ...               ...                ...            ...
# 90831          0.026580          0.059435       52078.886692   1.230039e+07
# 90832          0.016771          0.037501       46114.605073   5.432121e+07
# 90833          0.031956          0.071456        7566.807732   2.840077e+07
# 90834          0.007321          0.016370       69199.154484   6.869206e+07
# 90835          0.039862          0.089133       27024.455553   5.977213e+07
#
#        absolute_magnitude
# 0                   16.73
# ...

# %%
#plot multiple distributions in dataset 
fig= ses.pairplot(x)

# %%
knn =KNeighbor(n_neighbors=1)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
best_score = knn.score(x_test,y_test)

# %%
for i in range(1,15):
    knn2 =KNeighbor(n_neighbors=i)
    knn2.fit(x_train,y_train)
    temp_score = knn2.score(x_test,y_test)
    if(temp_score>best_score):
        knn=knn2
        best_score=temp_score

# %%
print(best_score)
# Out:
# 0.9011412425232102
